# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamron0829/week1/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#problem 1

scores = [72 , 85 , 90 , 68 , 88]

print("Scores", scores )

average = sum(scores)/len(scores)
print("Average: ", average)

highest_score = max(scores)
lowest_score = min(scores)

print("Highest score: ", highest_score )
print("Lowest score: ", lowest_score )
# Out:
# Scores [72, 85, 90, 68, 88]
# Average:  80.6
# Highest score:  90
# Lowest score:  68

# %%
#problem 2

study_hours = [1 , 2 , 3 , 4 , 5]
exam_scores = [50 , 55 , 65 , 70 , 80]

for i in range (len(study_hours)):
  print("Input: ", study_hours[i], "hours -> Output: ", exam_scores[i], "marks")
# Out:
# Input:  1 hours -> Output:  50 marks
# Input:  2 hours -> Output:  55 marks
# Input:  3 hours -> Output:  65 marks
# Input:  4 hours -> Output:  70 marks
# Input:  5 hours -> Output:  80 marks

# %%
#problem 3

scores = [45 , 67 , 82 , 59]

def pass_fail(score):
  if score >= 60:
    return "Pass"
  else:
    return "Fail"

for score in scores:
  result = pass_fail(score)
  print("Input: ", score, "Output: ", result)
# Out:
# Input:  45 Output:  Fail
# Input:  67 Output:  Pass
# Input:  82 Output:  Pass
# Input:  59 Output:  Fail

# %%
#problem 4

sizes = [500 , 800 , 1000 , 1200]
prices = [50 , 80 , 100 , 130]

for i in range (len(sizes)):
  print("Size:", sizes[i], " Square meter -> Price:", prices[i],)

is_increasing = True
for i in range (1, len(prices)):
  if prices[i] <= prices[i-1]:
    is_increasing = False

if is_increasing:
  print("Positive trend")
else:
  print("Negative trend")
# Out:
# Size: 500  Square meter -> Price: 50
# Size: 800  Square meter -> Price: 80
# Size: 1000  Square meter -> Price: 100
# Size: 1200  Square meter -> Price: 130
# Positive trend

# %%
#problem 5

study_hours = [2 , 4 , 6 , 8]
scores = [55 , 65 , 75 , 85]

for i in range (len(study_hours)):
  print("Increased score for every two hours: ", scores[i]+1 - scores[i])
# Out:
# Increased score for every two hours:  1
# Increased score for every two hours:  1
# Increased score for every two hours:  1
# Increased score for every two hours:  1

# %%
scores = [35 , 58 , 62 , 74 , 89 , 45]

for i in range (len(scores)):
    if scores[i] >= 70:
        print("High")
    elif scores[i] >= 50:
         print("Medium")
    else:
        print("Low")
# Out:
# Low
# Medium
# Medium
# High
# High
# Low

# %%
#problem 7

ages = [18 , 20 , 22 , 24 , 26]
heights = [160 , 165 , 170 , 175 , 180]

for i in range (len(ages)):
  print("Age:", ages[i], "Height:", heights[i])

average_age = sum(ages)/len(ages)
average_height = sum(heights)/len(heights)

print("Average age: ", average_age)
print("Average height: ", average_height)

print("Briefly comment: height appears to increase with age))")
# Out:
# Age: 18 Height: 160
# Age: 20 Height: 165
# Age: 22 Height: 170
# Age: 24 Height: 175
# Age: 26 Height: 180
# Average age:  22.0
# Average height:  170.0
# Briefly comment: height appears to increase with age))
